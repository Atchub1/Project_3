# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in the dataframe
cta_df = pd.read_csv('../Resources/ctatweets.csv',  encoding = 'ISO-8859-1')
cta_df.head()
# Out:
#                                                tweet            user  \
# 0  RT @gjsibio: Northbound Red Line L Train at th...         MOFFITW
# 1  RT @cta: [Minor Delays / Reroute] 70 Division ...  transit_tweets
# 2  RT @cta: [Minor Delays / Reroute] 70 Division ...     huskeeman82
# 3  Hey, @cta. Please turn on the heaters. Winter ...        rkhavard
# 4  .@cta Kimball bound Brown line train experienc...   aspaulding777
#
#                         location                 date
# 0  uptown, chi-city â¶â¶â¶â¶  2019-10-22 23:59:06
# 1                            NaN  2019-10-22 23:50:28
# 2                    Chicago, IL  2019-10-22 23:46:38
# 3                    Chicago, IL  2019-10-22 23:44:53
# 4                    Chicago, IL  2019-10-22 23:09:48

# %%
cta_df['date'] = pd.to_datetime(cta_df['date']).dt.to_period('d')
cta_df.head()
# Out:
#                                                tweet            user  \
# 0  RT @gjsibio: Northbound Red Line L Train at th...         MOFFITW
# 1  RT @cta: [Minor Delays / Reroute] 70 Division ...  transit_tweets
# 2  RT @cta: [Minor Delays / Reroute] 70 Division ...     huskeeman82
# 3  Hey, @cta. Please turn on the heaters. Winter ...        rkhavard
# 4  .@cta Kimball bound Brown line train experienc...   aspaulding777
#
#                         location        date
# 0  uptown, chi-city â¶â¶â¶â¶  2019-10-22
# 1                            NaN  2019-10-22
# 2                    Chicago, IL  2019-10-22
# 3                    Chicago, IL  2019-10-22
# 4                    Chicago, IL  2019-10-22

# %%
# group by date
grouped_cta_df = cta_df.groupby(['date']).count()

grouped_cta_df.head(20)
# Out:
#             tweet  user  location
# date
# 2019-10-13     19    19        14
# 2019-10-14    249   249       169
# 2019-10-15    260   260       186
# 2019-10-16    214   214       155
# 2019-10-17    430   430       314
# 2019-10-18    393   393       288
# 2019-10-19    200   200       140
# 2019-10-20     83    83        62
# 2019-10-21    182   182       134
# 2019-10-22    171   171       113

# %%
# Filter the DataFrame down only to those columns to chart
date_and_tweet = grouped_cta_df[["tweet"]]

# # Set the index to be "date" so they will be used as labels
# date_and_tweet = date_and_tweet.set_index("date")

date_and_tweet.head()
# Out:
#             tweet
# date
# 2019-10-13     19
# 2019-10-14    249
# 2019-10-15    260
# 2019-10-16    214
# 2019-10-17    430

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
date_and_tweet.plot(kind="bar", color='r', figsize=(10,3), alpha=0.5, align="center")

# Set a title for the chart
plt.title("Number of tweets per day")
plt.xlabel("Date")
plt.ylabel("Number of Tweets")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1000">
